# %%
# %load_ext tensorboard
# %tensorboard --logdir logs
# Out:
#       <iframe id="tensorboard-frame-758520a01ad34899" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-758520a01ad34899");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
import tensorflow as tf
import os

log_dir = os.path.abspath("./logs/run1")
writer = tf.summary.create_file_writer(log_dir)

# Example log
with writer.as_default():
    tf.summary.scalar("test_scalar", 0.5, step=0)
    writer.flush()

# Start TensorBoard
notebook.start(f'--logdir {log_dir} --bind_all --port 6006')
